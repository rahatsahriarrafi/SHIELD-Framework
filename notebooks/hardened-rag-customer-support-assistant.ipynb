# %% [markdown]
# # SHIELD Demo B  -  Hardened RAG Customer Support
# Run from repo root: `python demos/demo_b_hardened_rag.py` or execute the cell below.

# %%
# %run ../demos/demo_b_hardened_rag.py
